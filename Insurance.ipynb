# %% [markdown]
# <a href="https://colab.research.google.com/github/AnkitSankhua/InsuranceLinearRegression/blob/main/Insurance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
import pandas as pd
df.head(20)
# Out:
#     age     sex     bmi  children smoker     region      charges
# 0    19  female  27.900         0    yes  southwest  16884.92400
# 1    18    male  33.770         1     no  southeast   1725.55230
# 2    28    male  33.000         3     no  southeast   4449.46200
# 3    33    male  22.705         0     no  northwest  21984.47061
# 4    32    male  28.880         0     no  northwest   3866.85520
# 5    31  female  25.740         0     no  southeast   3756.62160
# 6    46  female  33.440         1     no  southeast   8240.58960
# 7    37  female  27.740         3     no  northwest   7281.50560
# 8    37    male  29.830         2     no  northeast   6406.41070
# 9    60  female  25.840         0     no  northwest  28923.13692
# 10   25    male  26.220         0     no  northeast   2721.32080
# 11   62  female  26.290         0    yes  southeast  27808.72510
# 12   23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
df.tail(20)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1318   35    male  39.710         4     no  northeast  19496.71917
# 1319   39  female  26.315         2     no  northwest   7201.70085
# 1320   31    male  31.065         3     no  northwest   5425.02335
# 1321   62    male  26.695         0    yes  northeast  28101.33305
# 1322   62    male  38.830         0     no  southeast  12981.34570
# 1323   42  female  40.370         2    yes  southeast  43896.37630
# 1324   31    male  25.935         1     no  northwest   4239.89265
# 1325   61    male  33.535         0     no  northeast  13143.33665
# 1326   42  female  32.870         0     no  northeast   7050.02130
# 1327   51    male  30.030         1     no  southeast   9377.90470
# 1328   23  female  24.225         2     no  northeast  22395.74424
# 1329   52    male  38.600         2     no  southwest  10325.20600
# 1330   57  female  25.740         2     no  southeast  12629.16560
# ...

# %% [markdown]
# Display Training Features : **Smoker**

# %%
  df["smoker"] = df["smoker"].astype("category")
  df["smoker"] = df["smoker"].cat.codes
  df
# Out:
#       age     sex     bmi  children  smoker     region      charges
# 0      19  female  27.900         0       1  southwest  16884.92400
# 1      18    male  33.770         1       0  southeast   1725.55230
# 2      28    male  33.000         3       0  southeast   4449.46200
# 3      33    male  22.705         0       0  northwest  21984.47061
# 4      32    male  28.880         0       0  northwest   3866.85520
# ...   ...     ...     ...       ...     ...        ...          ...
# 1333   50    male  30.970         3       0  northwest  10600.54830
# 1334   18  female  31.920         0       0  northeast   2205.98080
# 1335   18  female  36.850         0       0  southeast   1629.83350
# 1336   21  female  25.800         0       0  southwest   2007.94500
# 1337   61  female  29.070         0       1  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# Display Training Features : SEX

# %%
  df["sex"] = df["sex"].astype("category")
  df["sex"] = df["sex"].cat.codes
  df
# Out:
#       age  sex     bmi  children  smoker     region      charges
# 0      19    0  27.900         0       1  southwest  16884.92400
# 1      18    1  33.770         1       0  southeast   1725.55230
# 2      28    1  33.000         3       0  southeast   4449.46200
# 3      33    1  22.705         0       0  northwest  21984.47061
# 4      32    1  28.880         0       0  northwest   3866.85520
# ...   ...  ...     ...       ...     ...        ...          ...
# 1333   50    1  30.970         3       0  northwest  10600.54830
# 1334   18    0  31.920         0       0  northeast   2205.98080
# 1335   18    0  36.850         0       0  southeast   1629.83350
# 1336   21    0  25.800         0       0  southwest   2007.94500
# 1337   61    0  29.070         0       1  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# Display Training Features : **Region**

# %%
  df["region"] = df["region"].astype("category")
  df["region"] = df["region"].cat.codes
  df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# Check any null values....

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# Multiple regression formula is Y = m1x1 + m2x2 + m3x3 + ........ mnxn

# %% [markdown]
# We are dropping the column "Charges" because it is represented by y in the above formula. i.e. the values of charges would depend on the values of x in the multiple regression.

# %% [markdown]
# Display X axis --- Independent Variables

# %%
x = df.drop(columns = "charges")
x
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    0  27.900         0       1       3
# 1      18    1  33.770         1       0       2
# 2      28    1  33.000         3       0       2
# 3      33    1  22.705         0       0       1
# 4      32    1  28.880         0       0       1
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    1  30.970         3       0       1
# 1334   18    0  31.920         0       0       0
# 1335   18    0  36.850         0       0       2
# 1336   21    0  25.800         0       0       3
# 1337   61    0  29.070         0       1       1
#
# [1338 rows x 6 columns]

# %% [markdown]
# Display Y axis i.e. the dependent variable

# %%
y = df["charges"]
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %% [markdown]
# Now Using Train Test Split method to train the model

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3,random_state=0)

# %% [markdown]
# Machine Learning model implementation

# %% [markdown]
# Using multiple LineaR Regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %% [markdown]
# Training Dataset to the linear regression model

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Displaying the Y intercept

# %%
c = lr.intercept_
c
# Out:
# -11827.733141795718

# %% [markdown]
# Displaying The coefficients

# %%
m = lr.coef_
m
# Out:
# array([  256.5772619 ,   -49.39232379,   329.02381564,   479.08499828,
#        23400.28378787,  -276.31576201])

# %% [markdown]
# Build the training model and display the training data set prediction

# %%
y_pred_train = lr.predict(x_train)
y_pred_train
# Out:
# array([ 2074.0645306 ,  8141.81393908, 18738.94132528,  7874.86959064,
#         6305.12726989,  2023.19725425, 26861.18663021, 14932.93021746,
#        10489.56733846, 16254.02800921, 11726.39324257, 11284.0092172 ,
#        39312.16870908,  5825.91078917, 12314.92042527,  3164.68427134,
#        15406.30681252,  4648.58167988,  5011.79585436,  6012.4796038 ,
#        15349.49652486,  8970.97358853,  8780.43012222, 34229.60622887,
#         6700.80932636, 26943.25864121, 27280.48004482, 15477.83837581,
#         8825.62578924, 34394.38378457, 10177.85528603,  3901.18161227,
#        15608.58732963, 29584.76846515, 29453.37088923, 28132.67012427,
#        10003.22154888, 33049.08935397,  3963.45204974, 25461.54857001,
#         5656.76892592, 27993.86773531,  7049.4472544 , 15100.38851758,
#         2552.92266861, 35458.5756605 , 15250.90732084,  3190.28483443,
#         1768.85441295, 10155.17603664,  9937.89476088, 11225.91583863,
# ...

# %% [markdown]
# Visualizations

# %%
import matplotlib.pyplot as plt
plt.scatter(y_train,y_pred_train)
plt.xlabel("Original Charges")
plt.ylabel("Predicted Charges")
plt.show()

# %% [markdown]
# r2 score prediction accuracy. r2 score near 0 is the worst case scenario and r2 near 1 is the best case scenario.

# %%
from sklearn.metrics import r2_score
r2_score(y_train,y_pred_train)
# Out:
# 0.7306840408360217

# %%
y_pred_test = lr.predict(x_test)

# %% [markdown]
# Visualization of testing data set

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred_test)
plt.xlabel("Original Charges")
plt.ylabel("Predicted Charges")
plt.show()

# %%
r2_score(y_test,y_pred_test)
# Out:
# 0.7911113876316933

# %% [markdown]
# Difference between actual values and predicted values

# %%
pred_y_df = pd.DataFrame({"Actual Value" : y_test, "Predicted Value" : y_pred_test, "Difference" : y_test - y_pred_test})
pred_y_df[0:25]
# Out:
#       Actual Value  Predicted Value    Difference
# 578     9724.53000     11051.549098  -1327.019098
# 610     8547.69130      9821.281107  -1273.589807
# 569    45702.02235     37867.572209   7834.450141
# 1034   12950.07120     16125.705792  -3175.634592
# 198     9644.25250      6920.271325   2723.981175
# 981     4500.33925      3879.385498    620.953752
# 31      2198.18985      1448.919281    749.270569
# 1256   11436.73815     14390.177980  -2953.439830
# 1219    7537.16390      9022.951514  -1485.787614
# 1320    5425.02335      7458.833719  -2033.810369
# 613     6753.03800      4584.601255   2168.436745
# 1107   10493.94580     10309.988634    183.957166
# 1263    7337.74800      8693.038920  -1355.290920
# 406     4185.09790      4085.253935     99.843965
# 795    18310.74200     27551.607377  -9240.865377
# 970    10702.64240     11151.064072   -448.421672
# 824    12523.60480     11243.053682   1280.551118
# 141     3490.54910      5962.952112  -2472.403012
# ...

# %%
pred_y_df[200:300]
# Out:
#       Actual Value  Predicted Value   Difference
# 1110   11512.40500     13133.993244 -1621.588244
# 420    46889.26120     38538.798433  8350.462767
# 27     12268.63225     13749.626055 -1480.993805
# 982    19199.94400     28607.077975 -9407.133975
# 1005    4433.38770      6685.395034 -2252.007334
# ...            ...              ...          ...
# 283    11879.10405     13421.827768 -1542.723718
# 1120   34166.27300     26976.228195  7190.044805
# 1177    6496.88600      7100.747595  -603.861595
# 361     4751.07000      6788.442790 -2037.372790
# 870     8457.81800     12033.452469 -3575.634469
#
# [100 rows x 3 columns]

# %%
pred_y_df[60:150]
# Out:
#       Actual Value  Predicted Value    Difference
# 487     1253.93600      1611.878733   -357.942733
# 1301   46718.16325     38750.498101   7967.665149
# 435    13919.82290     15296.112255  -1376.289355
# 1144    9630.39700     11708.429585  -2078.032585
# 390    10736.87075     14076.396531  -3339.525781
# ...            ...              ...           ...
# 801    14313.84630     15875.566744  -1561.720444
# 443    28287.89766     15252.728531  13035.169129
# 1157   14426.07385      2382.170163  12043.903687
# 747     1627.28245      -120.560142   1747.842592
# 980    25517.11363     10834.078021  14683.035609
#
# [90 rows x 3 columns]

# %%
pred_y_df[0:300:5]
# Out:
#       Actual Value  Predicted Value    Difference
# 578     9724.53000     11051.549098  -1327.019098
# 981     4500.33925      3879.385498    620.953752
# 613     6753.03800      4584.601255   2168.436745
# 970    10702.64240     11151.064072   -448.421672
# 966    23967.38305     33448.598422  -9481.215372
# 319     4667.60765      9096.536070  -4428.928420
# 54      8059.67910      9035.989838   -976.310738
# 1032    4137.52270      5059.219886   -921.697186
# 863     5458.04645      3941.816146   1516.230304
# 1019   26018.95052      4994.741888  21024.208632
# 1178    2899.48935      5544.959214  -2645.469864
# 546     3268.84665      6965.996775  -3697.150125
# 487     1253.93600      1611.878733   -357.942733
# 483     9880.06800     13904.285645  -4024.217645
# 918    13041.92100     12273.004149    768.916851
# 342    13217.09450     12631.508693    585.585807
# 333    11658.37915     12011.544058   -353.164908
# 142    18972.49500     28976.626235 -10004.131235
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(pred_y_df["Actual Value"], label="Actual Value")
plt.plot(pred_y_df["Predicted Value"], label="Predicted Value")
plt.plot(pred_y_df["Difference"], label="Difference")

plt.xlabel("Data Point")
plt.ylabel("Value")
plt.title("Actual vs Predicted Values with Difference")
plt.legend()
plt.show()
